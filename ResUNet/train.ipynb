# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Input
from tensorflow.keras.models import Model

# %%
def batchnorm_relu(inputs):
    # Batch Normalization & ReLU
    x = BatchNormalization()(inputs)
    x = Activation("relu")(x)
    return x

# %%
def residual_block(inputs, num_filters, strides=1):
    # Convolutional Layers
    x = batchnorm_relu(inputs)
    x = Conv2D(num_filters, 3, padding="same", strides=strides)(x)
    x = batchnorm_relu(x)
    x = Conv2D(num_filters, 3, padding="same", strides=1)(x)

    # Shortcut Connection (Identity Mapping)
    s = Conv2D(num_filters, 1, padding="same", strides=strides)(inputs)

    # Addition
    x = x + s
    return x

# %%
# Decoder Block
def decoder_block(inputs, skip_features, num_filters):
    x = UpSampling2D((2, 2))(inputs)
    x = Concatenate()([x, skip_features])
    x = residual_block(x, num_filters, strides=1)
    return x

# %%
def build_resunet(input_shape, num_classes):
    # RESUNET Architecture

    inputs = Input(input_shape)

    # Endoder 1
    x = Conv2D(64, 3, padding="same", strides=1)(inputs)
    x = batchnorm_relu(x)
    x = Conv2D(64, 3, padding="same", strides=1)(x)
    s = Conv2D(64, 1, padding="same")(inputs)
    s1 = x + s

    # Encoder 2, 3
    s2 = residual_block(s1, 128, strides=2)
    s3 = residual_block(s2, 256, strides=2)

    # Bridge
    b = residual_block(s3, 512, strides=2)

    # Decoder 1, 2, 3
    x = decoder_block(b, s3, 256)
    x = decoder_block(x, s2, 128)
    x = decoder_block(x, s1, 64)

    # Classifier
    outputs = Conv2D(num_classes, 1, padding="same", activation="softmax")(x)

    # Model
    model = Model(inputs, outputs, name="RESUNET")
    return model

# %%
shape = (600, 600, 512)
model = build_resunet(shape, 11)

model.summary()
# Out:
# Model: "RESUNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 600, 600, 5  0           []
#                                 12)]
#
#  conv2d (Conv2D)                (None, 600, 600, 64  294976      ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 600, 600, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 600, 600, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 600, 600, 64  36928       ['activation[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 600, 600, 64  32832       ['input_1[0][0]']
#                                 )
#
#  tf.__operators__.add (TFOpLamb  (None, 600, 600, 64  0          ['conv2d_1[0][0]',
#  da)                            )                                 'conv2d_2[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 600, 600, 64  256        ['tf.__operators__.add[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 600, 600, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 300, 300, 12  73856       ['activation_1[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 300, 300, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  activation_2 (Activation)      (None, 300, 300, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 300, 300, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 300, 300, 12  8320        ['tf.__operators__.add[0][0]']
#                                 8)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 300, 300, 12  0          ['conv2d_4[0][0]',
#  mbda)                          8)                                'conv2d_5[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 300, 300, 12  512        ['tf.__operators__.add_1[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 300, 300, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_6 (Conv2D)              (None, 150, 150, 25  295168      ['activation_3[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 150, 150, 25  1024       ['conv2d_6[0][0]']
#  rmalization)                   6)
#
#  activation_4 (Activation)      (None, 150, 150, 25  0           ['batch_normalization_4[0][0]']
#                                 6)
#
#  conv2d_7 (Conv2D)              (None, 150, 150, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  conv2d_8 (Conv2D)              (None, 150, 150, 25  33024       ['tf.__operators__.add_1[0][0]']
#                                 6)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 150, 150, 25  0          ['conv2d_7[0][0]',
#  mbda)                          6)                                'conv2d_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 150, 150, 25  1024       ['tf.__operators__.add_2[0][0]']
#  rmalization)                   6)
#
#  activation_5 (Activation)      (None, 150, 150, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  conv2d_9 (Conv2D)              (None, 75, 75, 512)  1180160     ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 75, 75, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 75, 75, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 75, 75, 512)  2359808     ['activation_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 75, 75, 512)  131584      ['tf.__operators__.add_2[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 75, 75, 512)  0          ['conv2d_10[0][0]',
#  mbda)                                                            'conv2d_11[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 150, 150, 51  0           ['tf.__operators__.add_3[0][0]']
#                                 2)
#
#  concatenate (Concatenate)      (None, 150, 150, 76  0           ['up_sampling2d[0][0]',
#                                 8)                                'tf.__operators__.add_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 150, 150, 76  3072       ['concatenate[0][0]']
#  rmalization)                   8)
#
#  activation_7 (Activation)      (None, 150, 150, 76  0           ['batch_normalization_7[0][0]']
#                                 8)
#
#  conv2d_12 (Conv2D)             (None, 150, 150, 25  1769728     ['activation_7[0][0]']
#                                 6)
#
#  batch_normalization_8 (BatchNo  (None, 150, 150, 25  1024       ['conv2d_12[0][0]']
#  rmalization)                   6)
#
#  activation_8 (Activation)      (None, 150, 150, 25  0           ['batch_normalization_8[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 150, 150, 25  590080      ['activation_8[0][0]']
#                                 6)
#
#  conv2d_14 (Conv2D)             (None, 150, 150, 25  196864      ['concatenate[0][0]']
#                                 6)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 150, 150, 25  0          ['conv2d_13[0][0]',
#  mbda)                          6)                                'conv2d_14[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 300, 300, 25  0          ['tf.__operators__.add_4[0][0]']
#                                 6)
#
#  concatenate_1 (Concatenate)    (None, 300, 300, 38  0           ['up_sampling2d_1[0][0]',
#                                 4)                                'tf.__operators__.add_1[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 300, 300, 38  1536       ['concatenate_1[0][0]']
#  rmalization)                   4)
#
#  activation_9 (Activation)      (None, 300, 300, 38  0           ['batch_normalization_9[0][0]']
#                                 4)
#
#  conv2d_15 (Conv2D)             (None, 300, 300, 12  442496      ['activation_9[0][0]']
#                                 8)
#
#  batch_normalization_10 (BatchN  (None, 300, 300, 12  512        ['conv2d_15[0][0]']
#  ormalization)                  8)
#
#  activation_10 (Activation)     (None, 300, 300, 12  0           ['batch_normalization_10[0][0]']
#                                 8)
#
#  conv2d_16 (Conv2D)             (None, 300, 300, 12  147584      ['activation_10[0][0]']
#                                 8)
#
#  conv2d_17 (Conv2D)             (None, 300, 300, 12  49280       ['concatenate_1[0][0]']
#                                 8)
#
#  tf.__operators__.add_5 (TFOpLa  (None, 300, 300, 12  0          ['conv2d_16[0][0]',
#  mbda)                          8)                                'conv2d_17[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 600, 600, 12  0          ['tf.__operators__.add_5[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 600, 600, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'tf.__operators__.add[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 600, 600, 19  768        ['concatenate_2[0][0]']
#  ormalization)                  2)
#
#  activation_11 (Activation)     (None, 600, 600, 19  0           ['batch_normalization_11[0][0]']
#                                 2)
#
#  conv2d_18 (Conv2D)             (None, 600, 600, 64  110656      ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 600, 600, 64  256        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 600, 600, 64  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 600, 600, 64  36928       ['activation_12[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 600, 600, 64  12352       ['concatenate_2[0][0]']
#                                 )
#
#  tf.__operators__.add_6 (TFOpLa  (None, 600, 600, 64  0          ['conv2d_19[0][0]',
#  mbda)                          )                                 'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 600, 600, 11  715         ['tf.__operators__.add_6[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 8,553,803
# Trainable params: 8,547,403
# Non-trainable params: 6,400
# __________________________________________________________________________________________________
