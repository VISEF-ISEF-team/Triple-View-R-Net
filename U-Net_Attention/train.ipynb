# %% [markdown]
# ### Import Library

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras.layers as L
from tensorflow.keras.layers import PReLU

# %% [markdown]
# Activation functions: \
# https://www.tensorflow.org/api_docs/python/tf/keras/activations

# %% [markdown]
# ### Build Blocks

# %%
# RelU Activation
def conv_block_relu(x, num_filters): 
    x = L.Conv2D(num_filters, 3, padding="same")(x) 
    x = L.BatchNormalization()(x) 
    x = L.Activation("relu")(x)

    x = L.Conv2D(num_filters, 3, padding="same")(x) 
    x = L.BatchNormalization()(x) 
    x = L.Activation("relu")(x)

    return x

# %%
# PReLU activation
def conv_block_prelu(x, num_filters):
    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x) 
    x = PReLU()(x)
    
    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x) 
    x = PReLU()(x)
    
    return x

# %%
def encoder_block(x, num_filters):
    x = conv_block_prelu(x, num_filters)
    p = L.MaxPooling2D((2, 2))(x)
    return x, p

# %%
def attention_gate(g, s, num_filters): 
    Wg = L.Conv2D(num_filters, 1, padding="same")(g) 
    Wg = L.BatchNormalization()(Wg) 

    Ws = L.Conv2D(num_filters, 1, padding="same")(s)
    Ws = L.BatchNormalization()(Ws)

    output = L.Activation("relu")(Wg + Ws) 
    output = L.Conv2D(num_filters, 1, padding="same")(output) 
    output = L.Activation("sigmoid")(output) 

    return output * s

# %%
def decoder_block(x, s, num_filters): 
    x = L.UpSampling2D(interpolation="bilinear")(x) 
    s = attention_gate(x, s, num_filters)
    x = L.Concatenate()([x, s])
    x = conv_block_prelu(x, num_filters) 
    return x

# %%
def AttentionUnet(input_shape, num_classes):
    inputs = L.Input(input_shape)
    
    # Encoder
    s1, p1 = encoder_block(inputs, 64) 
    s2, p2 = encoder_block(p1, 128) 
    s3, p3 = encoder_block(p2, 256) 
    
    b1 = conv_block(p3, 512) 
    
    # Decoder
    d1 = decoder_block(b1, s3, 256) 
    d2 = decoder_block(d1, s2, 128)
    d3 = decoder_block(d2, s1, 64)
    
    # Output
    outputs = L.Conv2D(num_classes, 1, padding="same", activation="softmax")(d3)
    
    # Model
    model = Model(inputs, outputs, name="Attention-UNet")
    return model

# %%
input_shape = (256, 256, 256) 
model = AttentionUnet(input_shape, 11)
model.summary()
# Out:
# Model: "Attention-UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 256, 256, 2  0           []
#                                 56)]
#
#  conv2d_113 (Conv2D)            (None, 256, 256, 64  147520      ['input_10[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 256, 256, 64  256        ['conv2d_113[0][0]']
#  ormalization)                  )
#
#  p_re_lu_54 (PReLU)             (None, 256, 256, 64  4194304     ['batch_normalization_96[0][0]']
#                                 )
#
#  conv2d_114 (Conv2D)            (None, 256, 256, 64  36928       ['p_re_lu_54[0][0]']
#                                 )
#
#  batch_normalization_97 (BatchN  (None, 256, 256, 64  256        ['conv2d_114[0][0]']
#  ormalization)                  )
#
#  p_re_lu_55 (PReLU)             (None, 256, 256, 64  4194304     ['batch_normalization_97[0][0]']
#                                 )
#
#  max_pooling2d_15 (MaxPooling2D  (None, 128, 128, 64  0          ['p_re_lu_55[0][0]']
#  )                              )
#
#  conv2d_115 (Conv2D)            (None, 128, 128, 12  73856       ['max_pooling2d_15[0][0]']
#                                 8)
#
#  batch_normalization_98 (BatchN  (None, 128, 128, 12  512        ['conv2d_115[0][0]']
#  ormalization)                  8)
#
#  p_re_lu_56 (PReLU)             (None, 128, 128, 12  2097152     ['batch_normalization_98[0][0]']
#                                 8)
#
#  conv2d_116 (Conv2D)            (None, 128, 128, 12  147584      ['p_re_lu_56[0][0]']
#                                 8)
#
#  batch_normalization_99 (BatchN  (None, 128, 128, 12  512        ['conv2d_116[0][0]']
#  ormalization)                  8)
#
#  p_re_lu_57 (PReLU)             (None, 128, 128, 12  2097152     ['batch_normalization_99[0][0]']
#                                 8)
#
#  max_pooling2d_16 (MaxPooling2D  (None, 64, 64, 128)  0          ['p_re_lu_57[0][0]']
#  )
#
#  conv2d_117 (Conv2D)            (None, 64, 64, 256)  295168      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_100 (Batch  (None, 64, 64, 256)  1024       ['conv2d_117[0][0]']
#  Normalization)
#
#  p_re_lu_58 (PReLU)             (None, 64, 64, 256)  1048576     ['batch_normalization_100[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 64, 64, 256)  590080      ['p_re_lu_58[0][0]']
#
#  batch_normalization_101 (Batch  (None, 64, 64, 256)  1024       ['conv2d_118[0][0]']
#  Normalization)
#
#  p_re_lu_59 (PReLU)             (None, 64, 64, 256)  1048576     ['batch_normalization_101[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 32, 32, 256)  0          ['p_re_lu_59[0][0]']
#  )
#
#  conv2d_119 (Conv2D)            (None, 32, 32, 512)  1180160     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_102 (Batch  (None, 32, 32, 512)  2048       ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_40 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_102[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 32, 32, 512)  2359808     ['activation_40[0][0]']
#
#  batch_normalization_103 (Batch  (None, 32, 32, 512)  2048       ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_41 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_103[0][0]']
#
#  up_sampling2d_13 (UpSampling2D  (None, 64, 64, 512)  0          ['activation_41[0][0]']
#  )
#
#  conv2d_121 (Conv2D)            (None, 64, 64, 256)  131328      ['up_sampling2d_13[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 64, 64, 256)  65792       ['p_re_lu_59[0][0]']
#
#  batch_normalization_104 (Batch  (None, 64, 64, 256)  1024       ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 64, 64, 256)  1024       ['conv2d_122[0][0]']
#  Normalization)
#
#  tf.__operators__.add_13 (TFOpL  (None, 64, 64, 256)  0          ['batch_normalization_104[0][0]',
#  ambda)                                                           'batch_normalization_105[0][0]']
#
#  activation_42 (Activation)     (None, 64, 64, 256)  0           ['tf.__operators__.add_13[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 64, 64, 256)  65792       ['activation_42[0][0]']
#
#  activation_43 (Activation)     (None, 64, 64, 256)  0           ['conv2d_123[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 64, 64, 256)  0          ['activation_43[0][0]',
#  a)                                                               'p_re_lu_59[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 768)  0           ['up_sampling2d_13[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 64, 64, 256)  1769728     ['concatenate_13[0][0]']
#
#  batch_normalization_106 (Batch  (None, 64, 64, 256)  1024       ['conv2d_124[0][0]']
#  Normalization)
#
#  p_re_lu_60 (PReLU)             (None, 64, 64, 256)  1048576     ['batch_normalization_106[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 64, 64, 256)  590080      ['p_re_lu_60[0][0]']
#
#  batch_normalization_107 (Batch  (None, 64, 64, 256)  1024       ['conv2d_125[0][0]']
#  Normalization)
#
#  p_re_lu_61 (PReLU)             (None, 64, 64, 256)  1048576     ['batch_normalization_107[0][0]']
#
#  up_sampling2d_14 (UpSampling2D  (None, 128, 128, 25  0          ['p_re_lu_61[0][0]']
#  )                              6)
#
#  conv2d_126 (Conv2D)            (None, 128, 128, 12  32896       ['up_sampling2d_14[0][0]']
#                                 8)
#
#  conv2d_127 (Conv2D)            (None, 128, 128, 12  16512       ['p_re_lu_57[0][0]']
#                                 8)
#
#  batch_normalization_108 (Batch  (None, 128, 128, 12  512        ['conv2d_126[0][0]']
#  Normalization)                 8)
#
#  batch_normalization_109 (Batch  (None, 128, 128, 12  512        ['conv2d_127[0][0]']
#  Normalization)                 8)
#
#  tf.__operators__.add_14 (TFOpL  (None, 128, 128, 12  0          ['batch_normalization_108[0][0]',
#  ambda)                         8)                                'batch_normalization_109[0][0]']
#
#  activation_44 (Activation)     (None, 128, 128, 12  0           ['tf.__operators__.add_14[0][0]']
#                                 8)
#
#  conv2d_128 (Conv2D)            (None, 128, 128, 12  16512       ['activation_44[0][0]']
#                                 8)
#
#  activation_45 (Activation)     (None, 128, 128, 12  0           ['conv2d_128[0][0]']
#                                 8)
#
#  tf.math.multiply_13 (TFOpLambd  (None, 128, 128, 12  0          ['activation_45[0][0]',
#  a)                             8)                                'p_re_lu_57[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 38  0           ['up_sampling2d_14[0][0]',
#                                 4)                                'tf.math.multiply_13[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 128, 128, 12  442496      ['concatenate_14[0][0]']
#                                 8)
#
#  batch_normalization_110 (Batch  (None, 128, 128, 12  512        ['conv2d_129[0][0]']
#  Normalization)                 8)
#
#  p_re_lu_62 (PReLU)             (None, 128, 128, 12  2097152     ['batch_normalization_110[0][0]']
#                                 8)
#
#  conv2d_130 (Conv2D)            (None, 128, 128, 12  147584      ['p_re_lu_62[0][0]']
#                                 8)
#
#  batch_normalization_111 (Batch  (None, 128, 128, 12  512        ['conv2d_130[0][0]']
#  Normalization)                 8)
#
#  p_re_lu_63 (PReLU)             (None, 128, 128, 12  2097152     ['batch_normalization_111[0][0]']
#                                 8)
#
#  up_sampling2d_15 (UpSampling2D  (None, 256, 256, 12  0          ['p_re_lu_63[0][0]']
#  )                              8)
#
#  conv2d_131 (Conv2D)            (None, 256, 256, 64  8256        ['up_sampling2d_15[0][0]']
#                                 )
#
#  conv2d_132 (Conv2D)            (None, 256, 256, 64  4160        ['p_re_lu_55[0][0]']
#                                 )
#
#  batch_normalization_112 (Batch  (None, 256, 256, 64  256        ['conv2d_131[0][0]']
#  Normalization)                 )
#
#  batch_normalization_113 (Batch  (None, 256, 256, 64  256        ['conv2d_132[0][0]']
#  Normalization)                 )
#
#  tf.__operators__.add_15 (TFOpL  (None, 256, 256, 64  0          ['batch_normalization_112[0][0]',
#  ambda)                         )                                 'batch_normalization_113[0][0]']
#
#  activation_46 (Activation)     (None, 256, 256, 64  0           ['tf.__operators__.add_15[0][0]']
#                                 )
#
#  conv2d_133 (Conv2D)            (None, 256, 256, 64  4160        ['activation_46[0][0]']
#                                 )
#
#  activation_47 (Activation)     (None, 256, 256, 64  0           ['conv2d_133[0][0]']
#                                 )
#
#  tf.math.multiply_14 (TFOpLambd  (None, 256, 256, 64  0          ['activation_47[0][0]',
#  a)                             )                                 'p_re_lu_55[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 19  0           ['up_sampling2d_15[0][0]',
#                                 2)                                'tf.math.multiply_14[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 256, 256, 64  110656      ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_114 (Batch  (None, 256, 256, 64  256        ['conv2d_134[0][0]']
#  Normalization)                 )
#
#  p_re_lu_64 (PReLU)             (None, 256, 256, 64  4194304     ['batch_normalization_114[0][0]']
#                                 )
#
#  conv2d_135 (Conv2D)            (None, 256, 256, 64  36928       ['p_re_lu_64[0][0]']
#                                 )
#
#  batch_normalization_115 (Batch  (None, 256, 256, 64  256        ['conv2d_135[0][0]']
#  Normalization)                 )
#
#  p_re_lu_65 (PReLU)             (None, 256, 256, 64  4194304     ['batch_normalization_115[0][0]']
#                                 )
#
#  conv2d_136 (Conv2D)            (None, 256, 256, 11  715         ['p_re_lu_65[0][0]']
#                                 )
#
# ==================================================================================================
# Total params: 37,649,675
# Trainable params: 37,642,251
# Non-trainable params: 7,424
# __________________________________________________________________________________________________
